# %% [markdown]
# # Exploratory Data Analysis (EDA)
#
# This notebook contains initial exploratory analysis for the customer churn prediction project.
#
# ## Steps Covered
# - Data loading
# - Basic inspection
# - Handling missing values
# - Exploratory visualizations
